# %% [markdown]
# <a href="https://colab.research.google.com/github/EStalei/IC/blob/main/Ajuste_do_modelo_de_RL_Eike.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ajuste do modelo de RL**

# %% [markdown]
# **Disciplina: Tópicos em Inteligência Computacional**
#
# Instituto Federal do Norte de Minas Gerais Campus Montes Claros
#
# Curso: Ciência da Computação
#
# Professora: Luciana Balieiro Cosme
#
# Aluno: Eike Stálei Vieira Neves
#
#
#
# ---
#
# # Exercício 3
#
#
# Considere, as  características da base de dados Diabetes do exercício anterior:
#
# 1.   Para cada característica individualmente calcule o $R^2$, mostre o histograma e o gráfico de resíduos, e calcule o teste de normalidade. Compare o resultado com a característica "age".
# 2.   Adicionalmente, repita o processo com as duas características (regressão com duas variáveis).
#
#
# O código deve ser enviado ao Github e apresentado pelo Flipgrid.
#
# **Data: 14-10-2020**

# %% [markdown]
# # **Base de dados Diabetes**
# ---

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas
from sklearn import linear_model
from sklearn.datasets import load_diabetes
from statsmodels.stats.diagnostic import normal_ad
from sklearn.metrics import r2_score

diabetes = load_diabetes()


tabela = pandas.DataFrame(diabetes.data)
tabela.columns = diabetes.feature_names
tabela['y'] = diabetes.target


plt.hist(y)
plt.title('Histograma de y')
plt.show()

# %% [markdown]
# # **AGE**

# %%
X = tabela['age']
X_treinamento = X[:-20].array.to_numpy().reshape(-1,1)
X_teste = X[-20:].array.to_numpy().reshape(-1,1)

y = tabela['y']
y_treinamento = y[:-20]
y_teste = y[-20:].array.to_numpy().reshape(-1,1)


regr = linear_model.LinearRegression()

regr.fit(X_treinamento, y_treinamento)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
diabetes_y_pred = regr.predict(X_teste)

res = y_teste - diabetes_y_pred.reshape(-1,1)

plt.scatter(y=res, x=diabetes_y_pred, color='green', s=50, alpha=.6)
plt.hlines(y=0, xmin=-40, xmax=160, color='orange')
plt.ylabel('$ Resíduos')
plt.xlabel('$y Predito')
plt.title ('Gráficos de Resíduos')
plt.show()

plt.hist(res)
plt.title('Histograma dos resíduos da regressão')
plt.show()

p_value = normal_ad(res)[1]
print('\n p-value abaixo 0.05 geralmente significa não normal:', round(p_value[0],2))

print('\n R2:', r2_score(y_teste, diabetes_y_pred))
# Out:
#  p-value abaixo 0.05 geralmente significa não normal: 0.07
#
#  R2: -0.14368344751439177

# %% [markdown]
# # **SEX**

# %%
X_sex = tabela['sex']
X_tr_sex = X_sex[:-20].array.to_numpy().reshape(-1,1)
X_teste_sex = X_sex[-20:].array.to_numpy().reshape(-1,1)

regr = linear_model.LinearRegression()

regr.fit(X_tr_sex, y_treinamento)
diabetes_y_pred_sex = regr.predict(X_teste_sex)

res_sex = y_teste - diabetes_y_pred_sex.reshape(-1,1)

plt.scatter(y=res_sex, x=diabetes_y_pred_sex, color='green', s=50, alpha=.6)
plt.hlines(y=0, xmin=-40, xmax=160, color='orange')
plt.ylabel('$ Resíduos')
plt.xlabel('$y Predito')
plt.title ('Gráficos de Resíduos SEX')
plt.show()

plt.hist(res_sex)
plt.title('Histograma dos resíduos da regressão SEX')
plt.show()

p_value = normal_ad(res_sex)[1]
print('\n p-value abaixo 0.05 geralmente significa não normal:', round(p_value[0],2))
print('\n R2:', r2_score(y_teste, diabetes_y_pred_sex))
# Out:
#  p-value abaixo 0.05 geralmente significa não normal: 0.05
#
#  R2: -0.13883792137588857

# %% [markdown]
# # **BMI**

# %%
X_bmi = tabela['bmi']
X_tr_bmi = X_bmi[:-20].array.to_numpy().reshape(-1,1)
X_teste_bmi = X_bmi[-20:].array.to_numpy().reshape(-1,1)

regr = linear_model.LinearRegression()

regr.fit(X_tr_bmi, y_treinamento)
diabetes_y_pred_bmi = regr.predict(X_teste_bmi)

res_b = y_teste - diabetes_y_pred_bmi.reshape(-1,1)

plt.scatter(y=res_b, x=diabetes_y_pred_bmi, color='green', s=50, alpha=.6)
plt.hlines(y=0, xmin=-40, xmax=240, color='orange')
plt.ylabel('$ Resíduos')
plt.xlabel('$y Predito')
plt.title ('Gráficos de Resíduos BMI')
plt.show()

plt.hist(res_b)
plt.title('Histograma dos resíduos da regressão BMI')
plt.show()

p_value = normal_ad(res_b)[1]
print('\n p-value abaixo 0.05 geralmente significa não normal:', round(p_value[0],2))
print('\n R2:', r2_score(y_teste, diabetes_y_pred_bmi))
# Out:
#  p-value abaixo 0.05 geralmente significa não normal: 0.51
#
#  R2: 0.47257544798227147

# %% [markdown]
# # **BP**

# %%
X_bp = tabela['bp']
X_tr_bp = X_bp[:-20].array.to_numpy().reshape(-1,1)
X_teste_bp = X_bp[-20:].array.to_numpy().reshape(-1,1)

regr = linear_model.LinearRegression()

regr.fit(X_tr_bp, y_treinamento)
diabetes_y_pred_bp = regr.predict(X_teste_bp)

res_bp = y_teste - diabetes_y_pred_bp.reshape(-1,1)

plt.scatter(y=res_bp, x=diabetes_y_pred_bp, color='green', s=50, alpha=.6)
plt.hlines(y=0, xmin=-40, xmax=240, color='orange')
plt.ylabel('Resíduos')
plt.xlabel('Predito')
plt.title ('Gráficos de Resíduos BP')
plt.show()

plt.hist(res_bp)
plt.title('Histograma dos resíduos da regressão BP')
plt.show()

p_value = normal_ad(res_bp)[1]
print('\n p-value abaixo 0.05 geralmente significa não normal:', round(p_value[0],2))
print('\n R2:', r2_score(y_teste, diabetes_y_pred_bp))
# Out:
#  p-value abaixo 0.05 geralmente significa não normal: 0.18
#
#  R2: 0.15995117339547205

# %% [markdown]
# # **S1**

# %%
X_s1 = tabela['s1']
X_tr_s1 = X_s1[:-20].array.to_numpy().reshape(-1,1)
X_teste_s1 = X_s1[-20:].array.to_numpy().reshape(-1,1)

regr = linear_model.LinearRegression()

regr.fit(X_tr_s1, y_treinamento)
diabetes_y_pred_s1 = regr.predict(X_teste_s1)

res_s1 = y_teste - diabetes_y_pred_s1.reshape(-1,1)

plt.scatter(y=res_s1, x=diabetes_y_pred_s1, color='green', s=50, alpha=.6)
plt.hlines(y=0, xmin=-40, xmax=190, color='orange')
plt.ylabel('$ Resíduos')
plt.xlabel('$y Predito')
plt.title ('Gráficos de Resíduos S1')
plt.show()

plt.hist(res_s1)
plt.title('Histograma dos resíduos da regressão S1')
plt.show()

p_value = normal_ad(res_s1)[1]
print('\n p-value abaixo 0.05 geralmente significa não normal:', round(p_value[0],2))
print('\n R2:', r2_score(y_teste, diabetes_y_pred_s1))
# Out:
#  p-value abaixo 0.05 geralmente significa não normal: 0.11
#
#  R2: -0.16094176987655562

# %% [markdown]
# # **S2**

# %%
X_s2 = tabela['s2']
X_tr_s2 = X_s2[:-20].array.to_numpy().reshape(-1,1)
X_teste_s2 = X_s2[-20:].array.to_numpy().reshape(-1,1)

regr = linear_model.LinearRegression()

regr.fit(X_tr_s2, y_treinamento)
diabetes_y_pred_s2 = regr.predict(X_teste_s2)

res_s2 = y_teste - diabetes_y_pred_s2.reshape(-1,1)

plt.scatter(y=res_s2, x=diabetes_y_pred_s2, color='green', s=50, alpha=.6)
plt.hlines(y=0, xmin=-40, xmax=190, color='orange')
plt.ylabel('$ Resíduos')
plt.xlabel('$y Predito')
plt.title ('Gráficos de Resíduos S2')
plt.show()

plt.hist(res_s2)
plt.title('Histograma dos resíduos da regressão S2')
plt.show()

p_value = normal_ad(res_s2)[1]
print('\n p-value abaixo 0.05 geralmente significa não normal:', round(p_value[0],2))
print('\n R2:', r2_score(y_teste, diabetes_y_pred_s2))
# Out:
#  p-value abaixo 0.05 geralmente significa não normal: 0.02
#
#  R2: -0.15171870558113

# %% [markdown]
# # **S3**

# %%
X_s3 = tabela['s3']
X_tr_s3 = X_s3[:-20].array.to_numpy().reshape(-1,1)
X_teste_s3 = X_s3[-20:].array.to_numpy().reshape(-1,1)

regr = linear_model.LinearRegression()

regr.fit(X_tr_s3, y_treinamento)
diabetes_y_pred_s3 = regr.predict(X_teste_s3)

res_s3 = y_teste - diabetes_y_pred_s3.reshape(-1,1)

plt.scatter(y=res_s3, x=diabetes_y_pred_s3, color='green', s=50, alpha=.6)
plt.hlines(y=0, xmin=-40, xmax=210, color='orange')
plt.ylabel('$ Resíduos')
plt.xlabel('$y Predito')
plt.title ('Gráficos de Resíduos S3')
plt.show()

plt.hist(res_s3)
plt.title('Histograma dos resíduos da regressão S3')
plt.show()

p_value = normal_ad(res_s3)[1]
print('\n p-value abaixo 0.05 geralmente significa não normal:', round(p_value[0],2))
print('\n R2:', r2_score(y_teste, diabetes_y_pred_s3))
# Out:
#  p-value abaixo 0.05 geralmente significa não normal: 0.32
#
#  R2: 0.060610607792839555

# %% [markdown]
# # **S4**

# %%
X_s4 = tabela['s4']
X_tr_s4 = X_s4[:-20].array.to_numpy().reshape(-1,1)
X_teste_s4 = X_s4[-20:].array.to_numpy().reshape(-1,1)

regr = linear_model.LinearRegression()

regr.fit(X_tr_s4, y_treinamento)
diabetes_y_pred_s4 = regr.predict(X_teste_s4)

res_s4 = y_teste - diabetes_y_pred_s4.reshape(-1,1)

plt.scatter(y=res_s4, x=diabetes_y_pred_s4, color='green', s=50, alpha=.6)
plt.hlines(y=0, xmin=-40, xmax=240, color='orange')
plt.ylabel('$ Resíduos')
plt.xlabel('$y Predito')
plt.title ('Gráficos de Resíduos S4')
plt.show()

plt.hist(res_s4)
plt.title('Histograma dos resíduos da regressão S4')
plt.show()

p_value = normal_ad(res_s4)[1]
print('\n p-value abaixo 0.05 geralmente significa não normal:', round(p_value[0],2))
print('\n R2:', r2_score(y_teste, diabetes_y_pred_s4))
# Out:
#  p-value abaixo 0.05 geralmente significa não normal: 0.05
#
#  R2: -0.004070338973065413

# %% [markdown]
# # **S5**

# %%
X_s5 = tabela['s5']
X_tr_s5 = X_s5[:-20].array.to_numpy().reshape(-1,1)
X_teste_s5 = X_s5[-20:].array.to_numpy().reshape(-1,1)

regr = linear_model.LinearRegression()

regr.fit(X_tr_s5, y_treinamento)
diabetes_y_pred_s5 = regr.predict(X_teste_s5)

res_s5 = y_teste - diabetes_y_pred_s5.reshape(-1,1)

plt.scatter(y=res_s5, x=diabetes_y_pred_s5, color='green', s=50, alpha=.6)
plt.hlines(y=0, xmin=-40, xmax=240, color='orange')
plt.ylabel('$ Resíduos')
plt.xlabel('$y Predito')
plt.title ('Gráficos de Resíduos S5')
plt.show()

plt.hist(res_s5)
plt.title('Histograma dos resíduos da regressão S5')
plt.show()

p_value = normal_ad(res_s5)[1]
print('\n p-value abaixo 0.05 geralmente significa não normal:', round(p_value[0],2))
print('\n R2:', r2_score(y_teste, diabetes_y_pred_s5))
# Out:
#  p-value abaixo 0.05 geralmente significa não normal: 0.09
#
#  R2: 0.3948984231023219

# %% [markdown]
# # **S6**

# %%
X_s6 = tabela['s6']
X_tr_s6 = X_s6[:-20].array.to_numpy().reshape(-1,1)
X_teste_s6 = X_s6[-20:].array.to_numpy().reshape(-1,1)

regr = linear_model.LinearRegression()

regr.fit(X_tr_s6, y_treinamento)
diabetes_y_pred_s6 = regr.predict(X_teste_s6)

res_s6 = y_teste - diabetes_y_pred_s6.reshape(-1,1)

plt.scatter(y=res_s6, x=diabetes_y_pred_s6, color='green', s=50, alpha=.6)
plt.hlines(y=0, xmin=-40, xmax=240, color='orange')
plt.ylabel('$ Resíduos')
plt.xlabel('$y Predito')
plt.title ('Gráficos de Resíduos S6')
plt.show()

plt.hist(res_s6)
plt.title('Histograma dos resíduos da regressão S6')
plt.show()

p_value = normal_ad(res_s6)[1]
print('\n p-value abaixo 0.05 geralmente significa não normal:', round(p_value[0],2))
print('\n R2:', r2_score(y_teste, diabetes_y_pred_s6))
# Out:
#  p-value abaixo 0.05 geralmente significa não normal: 0.04
#
#  R2: -0.08990371992812851

# %% [markdown]
# # **AGE & BMI**

# %%
X_age_bmi = tabela[["age","bmi"]]
X_tr_age_bmi = X_age_bmi[:-20]
X_teste_age_bmi = X_age_bmi[-20:]

regr = linear_model.LinearRegression()

regr.fit(X_tr_age_bmi, y_treinamento)
diabetes_y_pred_age_bmi = regr.predict(X_teste_age_bmi)

res_age_bmi = y_teste - diabetes_y_pred_age_bmi.reshape(-1,1)

plt.scatter(y=res_age_bmi, x=diabetes_y_pred_age_bmi, color='green', s=50, alpha=.6)
plt.hlines(y=0, xmin=-40, xmax=245, color='orange')
plt.ylabel('$ Resíduos')
plt.xlabel('$y Predito')
plt.title ('Gráficos de Resíduos AGE & BMI')
plt.show()

plt.hist(res_age_bmi)
plt.title('Histograma dos resíduos da regressão AGE & BMI')
plt.show()

p_value = normal_ad(res_age_bmi)[1]
print('\n p-value abaixo 0.05 geralmente significa não normal:', round(p_value[0],2))
print('\n R2:', r2_score(y_teste, diabetes_y_pred_age_bmi))
# Out:
#  p-value abaixo 0.05 geralmente significa não normal: 0.48
#
#  R2: 0.46253134406436525

# %% [markdown]
# **Bibliografia**
#
# [Função r2_score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html#sklearn.metrics.r2_score)
#
#
# [Estatística Descritiva com Python](http://felipegalvao.com.br/blog/2016/03/31/estatistica-descritiva-com-python/)
#
# [Correlação: direto ao ponto](https://medium.com/brdata/correla%C3%A7%C3%A3o-direto-ao-ponto-9ec1d48735fb)
